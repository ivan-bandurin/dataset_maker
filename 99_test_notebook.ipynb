# %%
import time 
start = time.time()import dataremake

# %%
# importing pandas as pd 
import pandas as pd 
from numpy import nan

# %%
data_work = pd.read_csv('C:/Users/User/Desktop/Росстат/Проект_Датасеты/Датасеты/Демография/!Датасет_демография/1_inсoming_data/13-15/t_mt3_30.csv', 
                        sep = '\t',
                       encoding = 'cp1251')

# %%
data_work
# Out:
#     Международная миграция \n за  январь - декабрь  2020 г   \
# 0                        Центральный федеральный округ
# 1                                                  NaN
# 2                                                № п/п
# 3                                                  NaN
# 4                                                    А
# ..                                                 ...
# 262                                                NaN
# 263                                                NaN
# 264                                                NaN
# 265                                                NaN
# 266                                                NaN
#
#                                             Unnamed: 1  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Для прибывших - страна откуда прибыли или посл...
# 3                                                  NaN
# ...

# %%
# importing pandas as pd 
import pandas as pd 
from numpy import nan
  
# list of name, degree, score
nme = ["aparna", "pankaj", "sudhir", "Geeku"]
deg = ["MBA", "BCA", "M.Tech", "MBA"]
scr = [90, 40, 80, 98]
scr_2 = [90, nan, 80, 98]
  
# dictionary of lists 
dict = {'name': nme, 'degree': deg, 'score': scr, 'score_2': scr_2} 
    
df_2 = pd.DataFrame(dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-013646e96b13> in <module>
#      12 dict = {'name': nme, 'degree': deg, 'score': scr, 'score_2': scr_2}
#      13
# ---> 14 df_2 = pd.DataFrame(dict)
#      15
#
# ~\anaconda3\envs\practicum\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\envs\practicum\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# ...

# %%
df_1.describe()
# Out:
#            score    score_2
# count   4.000000   4.000000
# mean   77.000000  67.000000
# std    25.742313  45.269563
# min    40.000000   0.000000
# 25%    70.000000  60.000000
# 50%    85.000000  85.000000
# 75%    92.000000  92.000000
# max    98.000000  98.000000

# %%
df_2.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
# name       4 non-null object
# degree     4 non-null object
# score      4 non-null int64
# score_2    3 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 256.0+ bytes

# %% [markdown]
# ### Загрузка библиотек

# %% [markdown]
# ### Объявление функций

# %% [markdown]
# ### Загрузка датасетов

# %% [markdown]
# ### Работа с датасетами

# %%
end = time.time()
duration = end-start
print(int(duration), 'сек. или', int(duration//60), 'мин. и ', int(duration % 60), 'сек.')
